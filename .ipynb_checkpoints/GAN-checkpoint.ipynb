# %%
from utils import *
from GAN import *
import numpy as np
import torch
from torch.autograd import Variable

# %%
latent_dim = 2 # 2d Gaussian
HIDDEN_SIZE = 128
EPOCH_SIZE = 20000
BATCH_SIZE = 1000

# %%
gan = GAN(latent_dim, HIDDEN_SIZE)

# %%
for epoch in range(EPOCH_SIZE):
    real_normals = create_distribution(BATCH_SIZE)
    z = Variable(torch.FloatTensor(np.random.normal(0,1, (batch_size,latent_dim))))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-8b15235e5bd2> in <module>()
#       1 for epoch in range(EPOCH_SIZE):
# ----> 2     real_normals = create_distribution(BATCH_SIZE)
#       3     z = Variable(torch.FloatTensor(np.random.normal(0,1, (batch_size,latent_dim))))
#
# ~/am221/pacgan/utils.py in create_distribution(batch_size, num_components)
#       3
#       4 def create_distribution(batch_size, num_components=25):
# ----> 5     '''
#       6     create 2D Gaussian grid data
#       7     '''
#
# NameError: name 'ds' is not defined
